# %%
import stripe

# List all customers
stripe.api_key = "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"

customer_objs = []

customers = stripe.Customer.list(limit=100)
for c in customers.auto_paging_iter():
    customer_objs.append(c)

# %%
len(customer_objs)
# Out:
# 472

# %%
emails = [c.email for c in customer_objs]
email_counts = {email: emails.count(email) for email in set(emails)}
dupe_email_counts = {k: v for k, v in email_counts.items() if v > 1}

print(*["\n".join(map(str, i)) for i in dupe_email_counts.items()], sep="\n\n")

# %%
customer_id_to_sub = {}

for c in customer_objs:
    c_subs = stripe.Subscription.list(customer=c.id, status="all")
    customer_id_to_sub[c.id] = c_subs

# %%
len(customer_id_to_sub)
# Out:
# 714

# %%
no_subs = {k: v for k, v in customer_id_to_sub.items() if len(v) < 1}
no_subs
len(no_subs)

# print(no_subs.items()

for k, v in no_subs.items():
    print(k, len(v))

# for c_id, _ in no_subs.items():
#     stripe.Customer.delete(c_id)
# Out:
# cus_QcWwZlGwJIlYXc 0
# cus_Qd9cAfFWQJBOfX 0
# cus_QhKBuEeAiurbpx 0
# cus_QjOG9N9HzbtYGk 0
# cus_QunrVYvgT51jP0 0
# cus_QxwyeG3IVMox0L 0
# cus_QyDO9rYBZyNAyZ 0
# cus_QzKMno38a9mFBf 0
# cus_R0nStCIGykmdJF 0
# cus_R0nTJnW24lrz8L 0
# cus_R0wbG0U6LzJC0h 0
# cus_R18pRuoUbn2e9z 0
# cus_R1AEydgmNIndEO 0
# cus_R1BRsijNocc1Oy 0
# cus_R1E11m2eM0BmqA 0
# cus_R1HCLaj6oxwr1x 0
# cus_R1JiliEXo9iXC2 0
# cus_R1OsGhO8Ux6NYA 0
# cus_R1aVVxOmvYUDPl 0
# cus_R1bDbqQKC08xnj 0
# cus_R1ejmn3UcWEpW4 0
# cus_R1tIcl4ewAdwz9 0
# cus_R1wtJYPRixhAS2 0
# cus_R1wuLsfJCrV3zC 0
# cus_R1zaugX3CaOX7s 0
# cus_R2Gvheo1zZEoRQ 0
# cus_R2JAiJ4X2799sK 0
# cus_R2MPPXPM5yH5Tn 0
# cus_R2PurXE0xXQnJY 0
# cus_R2PzIvIjGccCtu 0
# cus_R2SsXnF9rDtUb3 0
# cus_R2XZV4F3qogvRc 0
# cus_R2g71WKncYJCw7 0
# cus_R2gvLN7kDdPVhB 0
# cus_R2mAVUJOzgzBSW 0
# cus_R2mWOcZxHo5G7s 0
# cus_R2p10HPVwXkJAG 0
# cus_R2qDuNQyRAhjeF 0
# cus_R2tQHobldvJsXi 0
# cus_R30hYv30dgMyx4 0
# cus_R32RnihFhGYnCM 0
# cus_R33NjXflQuccDP 0
# cus_R34otCmCuVvl4U 0
# ...

# %%
subs = {k: v for k, v in customer_id_to_sub.items() if len(v) > 0}
# Out:
# {'cus_SvUPbxWPSLuKtO': <ListObject list at 0x118acf890> JSON: {
#    "data": [
#      {
#        "application": null,
#        "application_fee_percent": null,
#        "automatic_tax": {
#          "disabled_reason": null,
#          "enabled": false,
#          "liability": null
#        },
#        "billing_cycle_anchor": 1756644861,
#        "billing_cycle_anchor_config": null,
#        "billing_mode": {
#          "type": "classic"
#        },
#        "billing_thresholds": null,
#        "cancel_at": null,
#        "cancel_at_period_end": false,
#        "canceled_at": null,
#        "cancellation_details": {
#          "comment": null,
#          "feedback": null,
#          "reason": null
#        },
#        "collection_method": "charge_automatically",
#        "created": 1756040061,
#        "currency": "usd",
#        "customer": "cus_SvUPbxWPSLuKtO",
#        "days_until_due": null,
#        "default_payment_method": "pm_1RzdR1IN2l1CEWdr6MvzvweX",
# ...

# %%
stripe.Customer.delete("cus_QWTYULaoIVxEMB")
# Out:
# <Customer customer id=cus_QWTYULaoIVxEMB at 0x11222b980> JSON: {
#   "deleted": true,
#   "id": "cus_QWTYULaoIVxEMB",
#   "object": "customer"
# }
