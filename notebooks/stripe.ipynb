# %%
# Archive prices generated by stripe CLI
# !stripe prices list --limit 100 --color off \
  | jq -r '.data[] | select(.unit_amount==1500) | .id' \
  | xargs -n1 -I{} stripe prices update {} --active=false
# Out:
# {
#   "id": "price_1RxR7GIJMmJNYMBWYFNdAcDZ",
#   "object": "price",
#   "active": false,
#   "billing_scheme": "per_unit",
#   "created": 1755516042,
#   "currency": "usd",
#   "custom_unit_amount": null,
#   "livemode": false,
#   "lookup_key": null,
#   "metadata": {},
#   "nickname": null,
#   "product": "prod_StDYUf6sH99H8c",
#   "recurring": {
#     "interval": "month",
#     "interval_count": 1,
#     "meter": null,
#     "trial_period_days": null,
#     "usage_type": "licensed"
#   },
#   "tax_behavior": "unspecified",
#   "tiers_mode": null,
#   "transform_quantity": null,
#   "type": "recurring",
#   "unit_amount": 1500,
#   "unit_amount_decimal": "1500"
# }
#
# {
#   "id": "price_1RxR6LIJMmJNYMBWS1xDPi7j",
#   "object": "price",
#   "active": false,
#   "billing_scheme": "per_unit",
#   "created": 1755515985,
#   "currency": "usd",
#   "custom_unit_amount": null,
#   "livemode": false,
#   "lookup_key": null,
#   "metadata": {},
#   "nickname": null,
# ...
